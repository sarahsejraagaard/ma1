# %% [markdown]
# # Mandatory Assignment 1
#
# #### Part II: Convolutional Neural Networks
#
# ***
#
# Please see the description of the assignment in the README file (section 2) <br>
# **Guide notebook**: [material/cnns_pytorch.ipynb](material/cnns_pytorch.ipynb)
#
# Table of contents:
# 1. Activate GPU
# 2. Load data
# 3. Inspect data
# 4. Convolutional neural network (**Where you will implement the CNN**)
# 5. Training hyperparameters (**Where you will add training parameters**)
# 6. Training
# 7. Plot loss and accuracy
# 8. Evaluate
#
# ***

# %%
# Load in relevant libraries, and alias where appropriate
import torch
import torch.nn as nn
import torchvision  # noqa
import torchvision.transforms as transforms
import torch.nn.functional as F  # noqa

import random
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# First, a bit of a hack in case your IDE wants to run the notebook from /`assignment/` and not the project root folder `/ma1`. We need the working directory to be `/ma1` for local imports to work.

# %%
# Ensure the working directory is set to the "ma1" folder.
while Path.cwd().name != "ma1" and "ma1" in str(Path.cwd()):
    os.chdir("..")  # Move up one directory
print(f"Working directory set to: {Path.cwd()}")
# Out:
# Working directory set to: /Users/sarahaagaard/Documents/sarah/HA IT/4. år/8. semester/Artificial Intelligence and Machine Learning/AIML25/mas/ma1

# %% [markdown]
# The following are local files imported into this notebook. This is one of the advantages of not using an online notebook like Google Colab or stand-alone notebooks like Jupyter: We can import local files and use them in our code, thus making it easier to manage our code and create a more modular structure.
#
# In `/src`, we have the following files:
# - `utils.py`: Contains utility functions (e.g., setting our device to GPU if available)
# - `data.py`: Contains functions to load data, train/validation split, and data augmentation
# - `training.py`: Contains a single but very important function: Our training loop.
# - `evaluation.py`: Contains functions to evaluate our model and produce a classification report
# - `visualization.py`: Contains functions to visualize our data and model performance
#
# You are encouraged to look at these files to understand how they work. Particularly, the training and evaluation files are important to understand how we train our model and evaluate its performance.

# %%
# local files
from src.utils import get_device
from src.data import load_torch_data, to_dataloader, train_val_split
from src.training import fit
from src.evaluation import evaluate
from src.visualize import plot_training_history, plot_probabilities, show_cifar_img

# %% [markdown]
# ### 1. Activate GPU
# If available. Note that this is not necessary, but it will speed up your training.

# %%
device = get_device()  # will default to 'cpu' if gpu is not available.
# Out:
# Running pytorch version (2.6.0.dev20241112) with backend = mps

# %%
torch.backends.mps.is_available()

print(torch.backends.mps.is_built())
# Out:
# True

# %% [markdown]
# ### 2. Load data

# %%
batch_size = 64  # number of samples per batch

torch.manual_seed(42)  # Set a random seed to ensure reproducibility

# %%
# Use transforms.compose method to reformat images for modeling,
# and save to variable preprocessing_stepss for later use.
# Think of this like sci-kit learn's pipeline method.
preprocessing_steps = transforms.Compose(
    [
        transforms.Resize((32,32)),             # Cifar-10 images are 32x32 (we resize the image to make sure its 32x32)
        transforms.RandomCrop(32, padding=4),   # Data augmentation step: Randomly crop the image to 32x32
        transforms.RandomHorizontalFlip(),      # Data augmentation step: Randomly flip image horizontally. we flip to make some random noise
        transforms.ToTensor(),                  # Convert the image to a pytorch tensor
        transforms.Normalize(                   # Normalize the image (i.e. scale the image to have a mean of 0 and a standard deviation of 1)
            mean=[0.4914, 0.4822, 0.4465],      # FYI: The mean of the CIFAR10 dataset for your convenience
            std=[0.2023, 0.1994, 0.2010]        # FYI the standard deviation of the CIFAR10 dataset
        )
    ]
)

# load the training/validation data
train_val = load_torch_data(
    dataset="CIFAR10",
    root = 'data',                     # The root directory where the dataset will be stored
    download = True,                   # If the dataset is not found at root, it will be downloaded
    train = True,                      # The train dataset (as opposed to the test dataset)
    transform = preprocessing_steps  # transformations to be applied to the dataset (see steps above)
)

# load the testing data
test = load_torch_data(
    dataset = "CIFAR10",
    root = 'data',
    download = True,
    train = False,
    transform = preprocessing_steps
)

f"{len(train_val)=}, {len(test)=}"
# Out:
# 'len(train_val)=50000, len(test)=10000'

# %%
# split training data in training and validation (just like train_test_split in sklearn)
train, val = train_val_split(train_val, val_ratio=0.2, seed=42)

f"{len(val)=}, {len(train)=}"
# Out:
# 'len(val)=10000, len(train)=40000'

# %%
# create dataloders for easy batch loading during training
train_loader = to_dataloader(train, batch_size = batch_size, shuffle = True)
val_loader = to_dataloader(val, batch_size = batch_size, shuffle = False)
test_loader = to_dataloader(test, batch_size = batch_size, shuffle = False)

# %% [markdown]
# ### 3. Inspect data

# %%
train_val, test
# Out:
# (Dataset CIFAR10
#      Number of datapoints: 50000
#      Root location: data
#      Split: Train
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(32, 32), interpolation=bilinear, max_size=None, antialias=True)
#                 RandomCrop(size=(32, 32), padding=4)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#                 Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
#             ),
#  Dataset CIFAR10
#      Number of datapoints: 10000
#      Root location: data
#      Split: Test
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(32, 32), interpolation=bilinear, max_size=None, antialias=True)
#                 RandomCrop(size=(32, 32), padding=4)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#                 Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
#             ))

# %%
# we can se the transformation steps above that we have applied

# %%
# Pick a random example from the training set
classes = train.dataset.classes
selection = random.randrange(len(train)-1)
image, label = train[selection]

show_cifar_img(image, label, classes)

# %% [markdown]
# ***

# %% [markdown]
# ### 4. Convolutional neural network

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        ######################
        # Convolutional layers
        # (pattern augmentation)
        ######################

        # Conv2D is a convolutional layer that applies a 2D convolution over an input signal.
        # TODO: set the in_channels, out_channels, kernel_size, stride, and padding parameters
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)  # in_channels is 3 because the image has 3 color channels (red, green, blue). 
        self.bn1 = nn.BatchNorm2d(32) # Normalisering after first convolution
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0) 

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1) 
        self.bn2 = nn.BatchNorm2d(64) # Normalisering after second convolution
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0) 


        # TODO: add more layers such as BatchNorm2d, MaxPool2d, and Conv2d

        ######################
        # Fully connected layers
        # (pattern recognition)
        ######################

        # "Flatten" converts a 2D matrix to a vector to be able to feed it to the fully
        # connected layers for classification. Should be between the convolutional and linear
        # layers (as the convolutional layers output 3D tensors, and the linear layers expect 1D vectors)
        self.flatten = nn.Flatten()

        # Linear is a fully connected layer that applies a linear transformation to the incoming data
        # TODO: set the in_features and out_features parameters
        self.fc1=nn.Linear(64*8*8,1024)
        self.fc2=nn.Linear(1024,10)


        # TODO: add more layers such as ReLU, Dropout, and Linear
        self.relu=nn.ReLU()

    def forward(self, x):

        ######################
        # Convolutional forward pass
        ######################
        x = self.conv1(x)
        x = self.bn1(x) # Normalisering
        x = self.relu(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.bn2(x) # Normalisering
        x = self.relu(x)
        x = self.pool2(x)
        
        # TODO: use the layers defined in the __init__ method to build the forward pass

        x = self.flatten(x) # flatten the tensor (convert 2D matrix to a vector)


        ######################
        # Fully connected forward pass
        ######################

        # TODO: use the layers defined in the __init__ method to build the forward pass
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)

        return x

# %%
# BatchNorm gør træningen hurtigere, stabiliserer aktiveringerne og reducerer risikoen for overfitting.

# %% [markdown]
# ### 5. Training hyperparameters

# %%
# Define relevant variables for the ML task
LEARNING_RATE = 1e-3 # TODO: Set the learning rate (the step size)
WEIGHT_DECAY = 1e-4 # TODO: Set the weight decay (i.e. L2 regularization)
NUM_EPOCHS = 20 # TODO: Set the number of epochs to train the model (=how many times we run through the data to learn all the signals of the data)

# %%
model = CNN().to(device) # FYI; Sends the model to the GPU if set earlier

# Set Loss function with criterion
criterion = nn.CrossEntropyLoss()

# Set optimizer with optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE, weight_decay = WEIGHT_DECAY)

# %% [markdown]
# ### 6. Training

# %%
# Define the learning rate scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

model, history = fit(
    model = model,
    train_loader = train_loader,
    val_loader = val_loader,
    optimizer = optimizer,
    criterion = criterion,
    num_epochs = NUM_EPOCHS,
    device = device,
    flatten = False  # don't flatten input tensors to 1D before passing to model. Convolutonal layers expect nD.
)

scheduler.step()
# Out:
# Epoch [1/20]: Train Loss: 1.5753 | Train Accuracy: 43.23% | Val Loss: 1.3719 | Val Accuracy: 50.61%
# Epoch [2/20]: Train Loss: 1.2343 | Train Accuracy: 55.23% | Val Loss: 1.1624 | Val Accuracy: 57.55%
# Epoch [3/20]: Train Loss: 1.0996 | Train Accuracy: 60.50% | Val Loss: 1.0737 | Val Accuracy: 61.47%
# Epoch [4/20]: Train Loss: 1.0210 | Train Accuracy: 63.41% | Val Loss: 0.9857 | Val Accuracy: 64.54%
# Epoch [5/20]: Train Loss: 0.9671 | Train Accuracy: 65.53% | Val Loss: 0.9488 | Val Accuracy: 66.18%
# Epoch [6/20]: Train Loss: 0.9190 | Train Accuracy: 67.63% | Val Loss: 0.8989 | Val Accuracy: 68.12%
# Epoch [7/20]: Train Loss: 0.8893 | Train Accuracy: 68.61% | Val Loss: 0.8678 | Val Accuracy: 69.32%
# Epoch [8/20]: Train Loss: 0.8476 | Train Accuracy: 69.81% | Val Loss: 0.8807 | Val Accuracy: 69.15%
# Epoch [9/20]: Train Loss: 0.8259 | Train Accuracy: 70.75% | Val Loss: 0.8767 | Val Accuracy: 69.72%
# Epoch [10/20]: Train Loss: 0.8024 | Train Accuracy: 71.75% | Val Loss: 0.8152 | Val Accuracy: 71.73%
# Epoch [11/20]: Train Loss: 0.7785 | Train Accuracy: 72.56% | Val Loss: 0.8283 | Val Accuracy: 70.99%
# Epoch [12/20]: Train Loss: 0.7626 | Train Accuracy: 73.27% | Val Loss: 0.8710 | Val Accuracy: 69.21%
# Epoch [13/20]: Train Loss: 0.7420 | Train Accuracy: 73.80% | Val Loss: 0.8044 | Val Accuracy: 72.03%
# Epoch [14/20]: Train Loss: 0.7276 | Train Accuracy: 74.36% | Val Loss: 0.8130 | Val Accuracy: 71.94%
# Epoch [15/20]: Train Loss: 0.7086 | Train Accuracy: 75.12% | Val Loss: 0.8086 | Val Accuracy: 71.94%
# Epoch [16/20]: Train Loss: 0.7018 | Train Accuracy: 75.32% | Val Loss: 0.7377 | Val Accuracy: 74.33%
# Epoch [17/20]: Train Loss: 0.6832 | Train Accuracy: 76.08% | Val Loss: 0.7283 | Val Accuracy: 74.28%
# Epoch [18/20]: Train Loss: 0.6789 | Train Accuracy: 76.29% | Val Loss: 0.7586 | Val Accuracy: 72.92%
# Epoch [19/20]: Train Loss: 0.6645 | Train Accuracy: 76.90% | Val Loss: 0.7413 | Val Accuracy: 73.95%
# Epoch [20/20]: Train Loss: 0.6570 | Train Accuracy: 77.16% | Val Loss: 0.7041 | Val Accuracy: 75.52%

# %%
## Scheduler forbedrer modelens træning ved gradvist at reducere learning raten, så den lærer hurtigt i starten og finpudser senere

# %% [markdown]
# ### 7. Plot loss and accuracy

# %%
plot_training_history(history)

# %%
# The training and validation loss (left plot):
    # both decrease over time, indicating effective learning. 
    # However, after a certain point (around epoch 10 in your case), the validation loss stops decreasing consistently and starts fluctuating, while training loss keeps decreasing.
    # This suggests overfitting!
    # -> the model learns noise or overly specific details from the training data rather than general patterns. As a result, it performs well on training data but inconsistently on validation data.

# The accuracy plot (right):
    # shows a steady increase in both training and validation accuracy
    # However, the gap between them widens slightly in later epochs, reinforcing the possibility of overfitting. 

# A potential fix could be early stopping or regularization techniques.

# %% [markdown]
# ### 8. Evaluate

# %% [markdown]
# Evaluate on training data, validation data and testing data.

# %%
evaluate(
    model = model,
    data_loader = train_loader,  # evaluate on training data
    device = device,
    criterion = criterion,
    flatten = False  # don't flatten input tensors to 1D. Convolutonal layers expect nD.
)
# Out:
# Evaluation Results:
# Loss: 0.6192, Accuracy: 78.26%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80      4027
#            1       0.86      0.90      0.88      3990
#            2       0.76      0.64      0.69      3994
#            3       0.60      0.66      0.63      4033
#            4       0.73      0.77      0.75      4037
#            5       0.71      0.67      0.69      3976
#            6       0.80      0.85      0.82      3975
#            7       0.86      0.78      0.82      3965
#            8       0.91      0.86      0.88      4002
#            9       0.85      0.88      0.86      4001
#
#     accuracy                           0.78     40000
#    macro avg       0.78      0.78      0.78     40000
# weighted avg       0.78      0.78      0.78     40000

# %%
# The model performs well on the training data, with a relatively low loss and a solid accuracy rate.

# %% [markdown]
# Inspect model predictions

# %%
# Get a single image and its label from the test dataset
index = np.random.randint(len(test))  # Randomly select an index
image, label = test[index]

# Prepare the image for prediction
model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    input_image = image.unsqueeze(0).to(device)                     # Add batch dimension and move to device
    outputs = model(input_image)                                    # Get model predictions
    probabilities = torch.nn.functional.softmax(outputs[0], dim=0)  # Apply softmax to get probabilities

plot_probabilities(
    image = image,
    label = label,
    probabilities = probabilities, 
    classes = test.classes,
    n = 5
)

# %%
evaluate(
    model = model,
    data_loader = val_loader,  # evaluate on validation data
    device = device,
    criterion = criterion,
    flatten = False
)
# Out:
# Evaluation Results:
# Loss: 0.7007, Accuracy: 75.50%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77       973
#            1       0.86      0.88      0.87      1010
#            2       0.73      0.61      0.67      1006
#            3       0.54      0.60      0.57       967
#            4       0.69      0.73      0.71       963
#            5       0.67      0.64      0.66      1024
#            6       0.80      0.82      0.81      1025
#            7       0.83      0.77      0.80      1035
#            8       0.89      0.84      0.86       998
#            9       0.79      0.86      0.83       999
#
#     accuracy                           0.76     10000
#    macro avg       0.76      0.75      0.75     10000
# weighted avg       0.76      0.76      0.76     10000

# %%
# The model's performance on the validation data is slightly worse than on the training data, which is expected, but the gap is not too large. 
# This might indicate slight overfitting.

# %%
evaluate(
    model = model,
    data_loader = test_loader,  # evaluate on testing data
    device = device,
    criterion = criterion,
    flatten = False
)
# Out:
# Evaluation Results:
# Loss: 0.7175, Accuracy: 75.18%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      1000
#            1       0.84      0.87      0.86      1000
#            2       0.73      0.61      0.66      1000
#            3       0.55      0.59      0.57      1000
#            4       0.70      0.73      0.71      1000
#            5       0.69      0.66      0.68      1000
#            6       0.78      0.83      0.80      1000
#            7       0.85      0.75      0.80      1000
#            8       0.87      0.82      0.84      1000
#            9       0.81      0.86      0.84      1000
#
#     accuracy                           0.75     10000
#    macro avg       0.75      0.75      0.75     10000
# weighted avg       0.75      0.75      0.75     10000

# %%
# Performance on the test data is similar to the validation data, suggesting the model generalizes reasonably well. 
# The slight drop in accuracy compared to the training data is expected when testing on unseen data.
